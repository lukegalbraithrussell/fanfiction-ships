# %%
import requests
import time
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

shipsDate = []
for i in range(1000,5000):
    quote_page = f"https://archiveofourown.org/tags/Harry%20Potter%20-%20J*d*%20K*d*%20Rowling/works?commit=Sort+and+Filter&page={i}&utf8=%E2%9C%93&work_search%5Bcomplete%5D=&work_search%5Bcrossover%5D=F&work_search%5Bdate_from%5D=&work_search%5Bdate_to%5D=&work_search%5Bexcluded_tag_names%5D=&work_search%5Blanguage_id%5D=&work_search%5Bother_tag_names%5D=&work_search%5Bquery%5D=&work_search%5Bsort_column%5D=revised_at&work_search%5Bwords_from%5D=&work_search%5Bwords_to%5D="


    #quote_page = f"https://archiveofourown.org/tags/Percy%20Jackson%20and%20the%20Olympians%20*a*%20Related%20Fandoms%20-%20All%20Media%20Types/works?commit=Sort+and+Filter&page={i}&utf8=%E2%9C%93&work_search%5Bcomplete%5D=&work_search%5Bcrossover%5D=F&work_search%5Bdate_from%5D=&work_search%5Bdate_to%5D=&work_search%5Bexcluded_tag_names%5D=&work_search%5Blanguage_id%5D=&work_search%5Bother_tag_names%5D=&work_search%5Bquery%5D=&work_search%5Bsort_column%5D=revised_at&work_search%5Bwords_from%5D=&work_search%5Bwords_to%5D="
    t0 = time.time()
    time.sleep(10)
    if i % 100 == 0:
        print(i)
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}    
    page = requests.get(quote_page, headers=headers)
    response_delay = time.time() - t0
    soup = BeautifulSoup(page.content, "html.parser")
    
    date = soup.find('p', attrs={'class': 'datetime'})
    date = date.text.strip()
    
    ships = soup.find_all('li', attrs={'class': 'relationships'})
    
    shipsList = []
    for i in range(0,len(ships)):
        shipsList.append(ships[i].text.strip())

    for i in shipsList:
        shipsDate.append([i,date])

df = pd.DataFrame(shipsDate, columns= ["Ship","Date"])
df.to_csv('HPFF1000.csv')
# Out:
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /usr/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# /usr/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# /usr/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /usr/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /usr/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# /usr/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# /usr/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# /usr/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x7fb9011f1588>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /usr/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /usr/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# /usr/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='archiveofourown.org', port=443): Max retries exceeded with url: /tags/Harry%20Potter%20-%20J*d*%20K*d*%20Rowling/works?commit=Sort+and+Filter&page=3761&utf8=%E2%9C%93&work_search%5Bcomplete%5D=&work_search%5Bcrossover%5D=F&work_search%5Bdate_from%5D=&work_search%5Bdate_to%5D=&work_search%5Bexcluded_tag_names%5D=&work_search%5Blanguage_id%5D=&work_search%5Bother_tag_names%5D=&work_search%5Bquery%5D=&work_search%5Bsort_column%5D=revised_at&work_search%5Bwords_from%5D=&work_search%5Bwords_to%5D= (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb9011f1588>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-7-1a7c852ee57b> in <module>
#      16         print(i)
#      17     headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
# ---> 18     page = requests.get(quote_page, headers=headers)
#      19     response_delay = time.time() - t0
#      20     soup = BeautifulSoup(page.content, "html.parser")
#
# /usr/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /usr/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='archiveofourown.org', port=443): Max retries exceeded with url: /tags/Harry%20Potter%20-%20J*d*%20K*d*%20Rowling/works?commit=Sort+and+Filter&page=3761&utf8=%E2%9C%93&work_search%5Bcomplete%5D=&work_search%5Bcrossover%5D=F&work_search%5Bdate_from%5D=&work_search%5Bdate_to%5D=&work_search%5Bexcluded_tag_names%5D=&work_search%5Blanguage_id%5D=&work_search%5Bother_tag_names%5D=&work_search%5Bquery%5D=&work_search%5Bsort_column%5D=revised_at&work_search%5Bwords_from%5D=&work_search%5Bwords_to%5D= (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fb9011f1588>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))

# %%
df = pd.DataFrame(shipsDate, columns= ["Ship","Date"])
df.to_csv('HPff.csv')

# %%
df
# Out:
#                                           Ship         Date
# 0                        Drarry - Relationship  01 Nov 2018
# 1                    Harry Potter/Draco Malfoy  01 Nov 2018
# 2                Hermione Granger/Draco Malfoy  01 Nov 2018
# 3                Hermione Granger/Harry Potter  01 Nov 2018
# 4                    Draco Malfoy/Harry Potter  01 Nov 2018
# 5                Hermione Granger/Draco Malfoy  01 Nov 2018
# 6                Hermione Granger/Harry Potter  01 Nov 2018
# 7                Hermione Granger/Draco Malfoy  01 Nov 2018
# 8                Hermione Granger/Harry Potter  01 Nov 2018
# 9                    Draco Malfoy/Harry Potter  01 Nov 2018
# 10                Hermione Granger/Ron Weasley  01 Nov 2018
# 11                   Draco Malfoy/Harry Potter  01 Nov 2018
# 12                    Sirius Black/Remus Lupin  01 Nov 2018
# 13                   Draco Malfoy/Harry Potter  01 Nov 2018
# 14       Ginny Weasley/Blaise Zabini Mentioned  01 Nov 2018
# 15     Hermione Granger/Ron Weasley background  01 Nov 2018
# 16                   Draco Malfoy/Harry Potter  01 Nov 2018
# 17                 Fred Weasley/George Weasley  01 Nov 2018
# 18               Fred Weasley & George Weasley  01 Nov 2018
# 19                  Draco Malfoy/Severus Snape  01 Nov 2018
# 20                   Draco Malfoy/Harry Potter  01 Nov 2018
# 21                Hermione Granger/Ron Weasley  01 Nov 2018
# 22                  Lavender Brown/Ron Weasley  01 Nov 2018
# 23                Draco Malfoy/Pansy Parkinson  01 Nov 2018
# 24                Michael Corner/Ginny Weasley  01 Nov 2018
# 25                   Draco Malfoy/Harry Potter  01 Nov 2018
# 26                  Harry Potter/Ginny Weasley  01 Nov 2018
# 27                  Harry Potter & Ron Weasley  01 Nov 2018
# 28               Harry Potter/Hermione Granger  01 Nov 2018
# 29              James Potter/Lily Evans Potter  01 Nov 2018
# ...                                        ...          ...
# 81214                      Newt - Relationship  22 Nov 2016
# 81215            Hermione Granger/Draco Malfoy  22 Nov 2016
# 81216            Hermione Granger/Draco Malfoy  22 Nov 2016
# 81217     Gellert Grindelwald/Albus Dumbledore  22 Nov 2016
# 81218             Scorpius Malfoy/Hugo Weasley  22 Nov 2016
# 81219                 Sirius Black/Remus Lupin  22 Nov 2016
# 81220                     Family Relationships  22 Nov 2016
# 81221                 Sirius Black/Remus Lupin  22 Nov 2016
# 81222             Hermione Granger/Ron Weasley  22 Nov 2016
# 81223            Hermione Granger/Draco Malfoy  22 Nov 2016
# 81224            Hermione Granger/Draco Malfoy  22 Nov 2016
# 81225             Hermione Granger/Ron Weasley  22 Nov 2016
# 81226          Teddy Lupin/James Sirius Potter  22 Nov 2016
# 81227             Hermione Granger/Ron Weasley  22 Nov 2016
# 81228            Hermione Granger/Draco Malfoy  22 Nov 2016
# 81229                Draco Malfoy/Harry Potter  22 Nov 2016
# 81230                Draco Malfoy/Harry Potter  22 Nov 2016
# 81231           Hermione Granger/Theodore Nott  22 Nov 2016
# 81232           Hermione Granger/Blaise Zabini  22 Nov 2016
# 81233     Scorpius Malfoy/Albus Severus Potter  22 Nov 2016
# 81234         Credence Barebone/Newt Scamander  22 Nov 2016
# 81235       Credence Barebone & Newt Scamander  22 Nov 2016
# 81236                   Harry Potter/Voldemort  22 Nov 2016
# 81237           Tina Goldstein/Percival Graves  22 Nov 2016
# 81238                                  implied  22 Nov 2016
# 81239         Queenie Goldstein/Jacob Kowalski  22 Nov 2016
# 81240                Draco Malfoy/Harry Potter  22 Nov 2016
# 81241     Scorpius Malfoy/Albus Severus Potter  22 Nov 2016
# 81242            Hermione Granger/Draco Malfoy  22 Nov 2016
# 81243            Hermione Granger/Draco Malfoy  22 Nov 2016
#
# [81244 rows x 2 columns]

# %%
#df2 = df1.append(df)
#df2 = df2.reset_index(drop=True)
#df2 = df2[['Ship','Date']]
#df2.to_csv('HPFF-4500.csv')
